# %%
import pandas as pd

df = pd.read_csv('data/twitter/tweets.csv')

# %%
filter_categories = {
    'water': ['drink', 'water','contamination', 'thirst', 'thirsty', 'to drink', 'hydrate'],
    'financial': ['Money', 'money', 'stocks', 'GDP', 'business', 'economy'],
    'health': ['injured', 'medical', 'death', 'casualitiy', 'hospital', 'accident', 'victims', 'casualities'],
    'building': ['houses','structure','structure', 'buildings','building', 'apartments', 'apartment'],
    'power': ['electricity', 'electric', 'power', 'utility', 'lights'],
    'transportation':[' road ',' roads ', ' bus ', ' car ', ' uber ', ' highway ', ' hwy ', ' traffic ', ' tollway ']
}

# %%
df['text'] = df['text'].str.lower()

# %%
df['category'] = False

# %%
filter_water = df['text'].str.contains('|'.join(filter_categories['water']), na=False)
filter_financial = df['text'].str.contains('|'.join(filter_categories['financial']), na=False)
filter_health = df['text'].str.contains('|'.join(filter_categories['health']), na=False)
filter_building = df['text'].str.contains('|'.join(filter_categories['building']), na=False)
filter_power = df['text'].str.contains('|'.join(filter_categories['power']), na=False)
filter_transportation = df['text'].str.contains('|'.join(filter_categories['transportation']), na=False)

df.loc[filter_water, 'category'] = 'water'
df.loc[filter_financial, 'category'] = 'financial'
df.loc[filter_health, 'category'] = 'health'
df.loc[filter_building, 'category'] = 'building'
df.loc[filter_power, 'category'] = 'power'
df.loc[filter_transportation, 'category'] = 'transportation'

# %%
f = df['category'] != False

# %%
df = df[f]

# %%
df
# Out:
#        index                                user_id created_at  \
# 3          3                               83866752  8/20/2017
# 5          6          {'$numberLong': '4586339233'}  8/20/2017
# 13        19  {'$numberLong': '818597386176069633'}  8/20/2017
# 14        20                               56832268  8/20/2017
# 18        24                             1301109288  8/20/2017
# ...      ...                                    ...        ...
# 438491   810                             1360313730  9/20/2017
# 438492   811                               21882231  9/20/2017
# 438495   815                              244281354  9/20/2017
# 438505   827                             1031144570  9/20/2017
# 438518   848                               22454135  9/20/2017
#
#                                                      text  state  \
# 3       who said a city couldn't come together ?!? alb...  Texas
# 5       the medical center of southeast ... is looking...  Texas
# 13      #trabajo en #austin, tx restaurant dishwasher ...  Texas
# 14      drinking a kolsch by @franconiabrew @ harvest ...  Texas
# 18      #nascar - drinking a pooltime ale by @bellsbre...  Texas
# ...                                                   ...    ...
# 438491  if you're looking for work in #houston, tx, ch...  Texas
# 438492  drinking a dreamcrusher double ipa by @deepell...  Texas
# 438495  serious accident in #pflugerville on kelly ln ...  Texas
# 438505  nits@utd ??????????\r\r\n#nits #family #friend...  Texas
# 438518  want to work in #dallas, tx? view our latest o...  Texas
#
#                   county   category
# 3          Dallas County      water
# 5       Jefferson County     health
# 13         Travis County      power
# 14         Collin County      water
# 18        Tarrant County      water
# ...                  ...        ...
# 438491     Harris County  financial
# 438492    Tarrant County      water
# 438495     Travis County     health
# 438505     Collin County   building
# 438518     Dallas County     health
#
# [42350 rows x 7 columns]

# %%
df.to_csv('filtered_tweets.csv')
