# %% [markdown]
# Transportation- keywords for filtering- road, bus, car, uber,highway, lyft, i10, sh6, traffic, tollway, hwy, metro, highways, i45, i69, i610, interstate10, interstate45, interstate69, interstate610
#
# Homes- keywords for filtering- House, Building, Home, School, Shelter, Groadshomes, Harris homes
#
# Power- electric, power, utility, lights, cell, phone, mobile, internet, network, telephone lines, electric lines,

# %%
import pandas as pd
import re
df = pd.read_csv('data/harvey_tweets.csv')
pd.options.display.max_colwidth = 2000
pd.set_option('display.max_rows', 100)

# %%
# fltr = df['text'].str.contains('(harvey)', na=False, regex=True)
# df[fltr]['text']

# %%
# fltr = df['text'].str.replace('(https://t\.co/*)','', regex=True)
# fltr = df['text'].str.replace('(@)','', regex=True)

# df[fltr]
f = df['text'].str.contains('harvey', na=False, regex=True, flags=re.IGNORECASE)
# f2 = fltr.str.contains(r'\b(building|house|home|school|shelter|groadshomes|Harris homes)\b', na=False, regex=True, flags=re.IGNORECASE)

# a = fltr[f]
# df[f].to_csv('harvey_t.csv')
df[f]
# Out:
#        index                                user_id created_at  \
# 7431     800                               30782296  8/20/2017
# 8885      36                             1691843972  8/20/2017
# 15489      9                             1253011800  8/25/2017
# 15496     17                               15369495  8/25/2017
# 15510     37                               58624342  8/25/2017
# ...      ...                                    ...        ...
# 437922    31  {'$numberLong': '808703232012910593'}  9/20/2017
# 437933    45                              522659494  9/20/2017
# 438000   131                              522659494  9/20/2017
# 438270   509  {'$numberLong': '805790223812743172'}  9/20/2017
# 438361   630                             1480278198  9/20/2017
#
#                                                                                                                                               text  \
# 7431                       It was great to meet the next Senator from The Great State of Texas, Beto O'Rourke! @ Harvey?? https://t.co/6uPyl97pAi
# 8885                       ??? Played Berzerk by Eminem and Flagpole Sitta by Harvey Danger at @DeliPlanetWF : https://t.co/Bb0pOxqntY @GetRockbot
# 15489                In between rain bands \r\r\n\r\r\n#tropicalstormforcewinds #harvey #victoria #Texas @ Victoria, Texas https://t.co/VQP0C3SPS6
# 15496                                      KSAT12 News @ 5pm: Tracking Harvey. https://t.co/von7rldzw1  #news #ksatnews?? https://t.co/lFqsdYbZdx
# 15510   The eyewall of Hurricane Harvey is close to moving onshore, with sustained hurricane-force winds arriving soon.?? https://t.co/zteXxwyEOw
# ...                                                                                                                                            ...
# 437922                       #bellydance event with #fusiondance #fundraiser to help#texas #teacher after Harvey. @ The?? https://t.co/8ZMekXwE0X
# 437933                             #fromtgerooftop #hurricaneharvey #roofrpairscheck  #roofphoto #fromthetop #highlevel?? https://t.co/FjfOX7bMbg
# 438000                                #hurricaneharvey #roofrepairs #hurricaneharvey2017 #afterthestorm #fixingtheroofs?? https://t.co/cgBoRjYKIv
# 438270             Hello to our lovely clients,\r\r\nIt??s weeks after #Hurricane #Harvey made landfall in the Houston?? https://t.co/0JV85YLuwr
# 438361                   After #hurricaneharvey hot, humid, soaked in perspiration riding #backroads and #countrytrails?? https://t.co/y7jVYNSRss
#
#         state            county
# 7431    Texas     Brazos County
# 8885    Texas    Wichita County
# 15489   Texas   Victoria County
# 15496   Texas      Bexar County
# 15510   Texas     Dallas County
# ...       ...               ...
# 437922  Texas  Fort Bend County
# 437933  Texas  Fort Bend County
# 438000  Texas  Fort Bend County
# 438270  Texas     Harris County
# 438361  Texas  Galveston County
#
# [9134 rows x 6 columns]

# %%
# data = pd.read_csv('filtered_harvey_t.csv')
# data['text']
# Out:
# 0         couldn't make it to the planned spot, so we'll have a drink here and then shelter at home. #staysafe #harvey... https://t.co/trnceky5ee
# 1                     finished up a strong first week of school and training. #riceowls #hurricaneharvey #hunkereddown?? https://t.co/ccetbcb9d5
# 2                           the calm before the #storm #harvey #hurricaneharvey #home #theheights #houston #shadyacres?? https://t.co/yuouzwwlwv
# 3                                                       tornado warned cell, angleton, tx #txwx #harvey @ angleton, texas https://t.co/2oshusck8l
# 4      bracing for harvey: resources for shelter, food, supplies, and transportation: with residents of the?? https://t.co/8vedzmwbns #teamninja
#                                                                           ...
# 553                                         pomona sees home sales increase as elementary school debuts and harvey passes https://t.co/lt9m7l5yt9
# 554                                           bear creek elementary students head??back to their home campus after harvey https://t.co/aeyzvph4wc
# 555                                         pomona sees home sales increase as elementary school debuts and harvey passes https://t.co/vdobdihmt2
# 556               grassroots &amp; black power alert: millions #harvey  $$$ are being raised &amp; distributed without?? https://t.co/fddyyfmooy
# 557                                           bear creek elementary students head??back to their home campus after harvey https://t.co/hywt0czsjm
# Name: text, Length: 558, dtype: object
